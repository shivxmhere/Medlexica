# %% [markdown]
# # MedLexica — QLoRA Training on Google Colab
# **Fine-tuning Phi-3-mini-4k-instruct on Indian Clinical Data**
# - Runtime: GPU (T4 recommended)
# - Estimated time: 3-4 hours
# - VRAM required: ~14GB

# %%
# Step 1: Install dependencies
# !pip install -q torch transformers peft bitsandbytes trl 
# !pip install -q datasets evaluate wandb accelerate
# !pip install -q bert-score sentence-transformers

# %%
# Step 2: Clone repo and setup
# !git clone https://github.com/shivxmhere/Medlexica.git
# %cd Medlexica
import os
os.environ["WANDB_PROJECT"] = "medlexica-hackathon"
os.environ["HF_TOKEN"] = "your_hf_token_here"

# %%
# Step 3: Verify GPU
import torch
print(f"GPU available: {torch.cuda.is_available()}")
print(f"GPU name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'No GPU'}")
if torch.cuda.is_available():
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %%
# Step 4: Build dataset
# !python training/dataset_builder.py

# %%
# Step 5: Run QLoRA fine-tuning
# !python training/train.py --config training/config.yaml

# %%
# Step 6: Run evaluation harness
# !python eval/run_eval.py

# %%
# Step 7: View results
import json
try:
    with open("eval/scorecard.json") as f:
        scores = json.load(f)
        
    print("=" * 60)
    print("MEDLEXICA EVALUATION RESULTS")
    print("=" * 60)
    for metric, values in scores["delta"].items():
        print(f"{metric:25s}: {values}")
except Exception as e:
    print(f"Error loading results: {e}")

# %% [markdown]
# ## Results
# After training, paste your scorecard.json results here.
# Update the README.md with real numbers.
# Share your W&B run link.
